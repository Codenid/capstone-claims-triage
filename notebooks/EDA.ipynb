# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
raw_data = pd.read_parquet(r"C:\Users\LENOVO\Documents\GitHub\capstone-claims-triage\data\raw\cfpb_reclamos_narrativa.parquet", engine="pyarrow")

# %%
raw_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3837184 entries, 0 to 3837183
# Data columns (total 16 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   Date received                 str
#  1   Product                       str
#  2   Sub-product                   str
#  3   Issue                         str
#  4   Sub-issue                     str
#  5   Consumer complaint narrative  str
#  6   Company public response       str
#  7   Company                       str
#  8   State                         str
#  9   ZIP code                      str
#  10  Tags                          str
#  11  Submitted via                 str
#  12  Date sent to company          str
#  13  Company response to consumer  str
#  14  Timely response?              str
#  15  Complaint ID                  str
# dtypes: str(16)
# memory usage: 5.1 GB

# %%
raw_data.head(6)
# Out:
#   Date received                                            Product  \
# 0    2023-04-21                        Checking or savings account
# 1    2023-07-13  Money transfer, virtual currency, or money ser...
# 2    2023-06-27                                           Mortgage
# 3    2024-05-06                                    Debt collection
# 4    2025-06-25                                       Student loan
# 5    2025-06-25                                       Student loan
#
#                       Sub-product  \
# 0                Checking account
# 1    International money transfer
# 2          Other type of mortgage
# 3                       Auto debt
# 4  Federal student loan servicing
# 5  Federal student loan servicing
#
#                                                Issue  \
# 0                                Managing an account
# 1                                      Fraud or scam
# 2                     Trouble during payment process
# ...

# %%
raw_data["Company response to consumer"].value_counts().plot(kind="bar", figsize=(10, 6))
# Out:
# <Axes: xlabel='Company response to consumer'>
